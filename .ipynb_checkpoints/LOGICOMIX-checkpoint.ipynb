# %% [markdown]
# # 述語計算

# %% [markdown]
# 述語計算では, 基本命題(または述語)は $P(a, b, c,\cdots)$ という形をもつ複合的対称であるとされ,
# ここで$P$はその言語の記号
# $a, b, c,\cdots$は定項または変項
#
# 例えば
# 命題の記号 = 年上の
# 定項 = プラトン
# x = 変項
# であるなら,
# 「年上の(プラトン, x)」はプラトンがxよりも年上であることを表す, 形式規則に従って正しく形成された命題となる.
# このタイプの命題は
# ブールの論理結合子 $\vee, \wedge,  \neg$ ならびに($\rightarrow$のこと?) で結合したり
# フレーゲの $\forall x$ や, $\exists x$ といった量化子で束縛することができる.
#
# したがって
# 「年上の(x, プラトン)が存在する」は「プラトンより年上の少なくともひとつの個体が存在する」
#
# 例えば
# あらゆる整数 $x$ は偶数 $x = 2y$ または奇数 $x = 2y + 1$ である
# という算術の定理は
# $$\forall x \exists y~(~x = 2y ~~or~~ x = 2y + 1~)$$
#
#  あらゆる $x$ について $x = 2y ~~or~~ x = 2y + 1$ のような $y$ が存在する.
#
#  一階述語論理と呼ばれる, 厳密に定義された述語計算では, 単純な数学的対称が変項値として用いられるのに対し
#  二階述語論理では変項は集合でもありえ, 「集合 $S$ が存在する」 といった言明が可能になる.
#
#  より強力なこの言語は, 既知のあらゆる

# %% [markdown]
# 吉のあらゆる数学を表すことができる丸1階述語論理 でも 2階述語論理でも拾伍計算における文が真である限りあるかはその分がどのようなモデルによって解釈される家に夜だから 例えば上にあげた単純な算術の定理 は 10+ -1 を通常のように解釈すれば 自然数において新となるが 10+の動画かけ倒しメスと解釈すれば get null null しかし そうした 解釈 とは独立して唇であるような分もあり それは妥当と呼ばれるなるこれはブールの結合した両下肢の基本的性質 柄本時生 満まる クルト ゲーデルの不完全性定理は 1階述語論理における妥当性を証明する為の男女男女の交流体験を提供している
